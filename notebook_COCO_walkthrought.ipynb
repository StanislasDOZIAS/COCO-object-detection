# %%
import fiftyone as fo
import fiftyone.zoo as foz

# %%
dataset = foz.load_zoo_dataset("coco-2017")
# Out:
# Downloading split 'train' to 'C:\Users\stani\fiftyone\coco-2017\train' if necessary
# Found annotations at 'C:\Users\stani\fiftyone\coco-2017\raw\instances_train2017.json'
# Images already downloaded
# Existing download of split 'train' is sufficient
# Downloading split 'validation' to 'C:\Users\stani\fiftyone\coco-2017\validation' if necessary
# Found annotations at 'C:\Users\stani\fiftyone\coco-2017\raw\instances_val2017.json'
# Images already downloaded
# Existing download of split 'validation' is sufficient
# Downloading split 'test' to 'C:\Users\stani\fiftyone\coco-2017\test' if necessary
# Found test info at 'C:\Users\stani\fiftyone\coco-2017\raw\image_info_test2017.json'
# Images already downloaded
# Existing download of split 'test' is sufficient
# Loading existing dataset 'coco-2017'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
session = fo.launch_app(dataset)
# Out:
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# #focontainer-d8777d27-5fbf-4eab-afa6-63350a0794c0 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-d8777d27-5fbf-4eab-afa6-63350a0794c0 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-d8777d27-5fbf-4eab-afa6-63350a0794c0:focus {
#   outline: none;
# }
# #fooverlay-d8777d27-5fbf-4eab-afa6-63350a0794c0 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-d8777d27-5fbf-4eab-afa6-63350a0794c0">
#    <div id="fooverlay-d8777d27-5fbf-4eab-afa6-63350a0794c0" style="display: none;">
#       <button id="foactivate-d8777d27-5fbf-4eab-afa6-63350a0794c0" >Activate</button>
#    </div>
#    <img src='data:image/png;base64,...' style="width: 100%; max-width: 1565px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-d8777d27-5fbf-4eab-afa6-63350a0794c0");
#      var overlay = document.getElementById("fooverlay-d8777d27-5fbf-4eab-afa6-63350a0794c0");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "d8777d27-5fbf-4eab-afa6-63350a0794c0" },
#               subscription: "d8777d27-5fbf-4eab-afa6-63350a0794c0"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %%
session.show()
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?context=ipython&subscription=2a99c886-e88a-4eae-82a8-e4e09e8076e0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Could not connect session, trying again in 10 seconds

# %%
from fiftyone import ViewField as F

person_view = (
    dataset
    .filter_labels("ground_truth", F("label") == "teddy bear")
    .sort_by(F("ground_truth.detections").length(), reverse=True)
)

# %%
session.view = person_view
# Out:
# Could not connect session, trying again in 10 seconds
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?context=ipython&subscription=53c980f1-ba71-4d73-9b2b-fcdf67a6d234"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18508\4116954131.py in <module>
# ----> 1 session.view = person_view
#
# c:\Users\stani\anaconda3\envs\coco\lib\site-packages\fiftyone\core\session\session.py in wrapper(session, *args, **kwargs)
#     211             session._client.send_event(StateUpdate(state=session._state))
#     212             if auto_show and session.auto and focx.is_notebook_context():
# --> 213                 session.show()
#     214
#     215             return result
#
# c:\Users\stani\anaconda3\envs\coco\lib\site-packages\fiftyone\core\session\session.py in wrapper(session, *args, **kwargs)
#     209                 session.freeze()
#     210             result = func(session, *args, **kwargs)
# --> 211             session._client.send_event(StateUpdate(state=session._state))
#     212             if auto_show and session.auto and focx.is_notebook_context():
#     213                 session.show()
#
# c:\Users\stani\anaconda3\envs\coco\lib\site-packages\fiftyone\core\session\client.py in send_event(self, event)
#     120         """
#     121         if not self._connected:
# --> 122             raise RuntimeError("Client is not connected")
#     123
#     124         self._post_event(event)
#
# RuntimeError: Client is not connected
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds

# %%
session.freeze()
# Out:
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
